# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import numpy as np
# ----> 2 import seaborn as sns
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
segments = np.load(r"D:\code_zongheng\foundation_model\saved_data\ecg_segments\3213671_0002.npy")

quas = np.load("D:\\code_zongheng\\foundation_model\\saved_data\\quality_labels\\3213671_0002.npy")
print(quas[:10])
print(len(quas))
# Out:
# [0.6969697  0.42424242 0.81818182 0.625      0.57575758 0.66666667
#  0.35294118 0.54545455 0.72727273 0.54545455]
# 90

# %%
plt.hist(quas, bins=10, color='skyblue', edgecolor='black')
plt.title("qualities histogram")
plt.xlabel("quality")
plt.ylabel("frequency")
plt.show()

# %%
plt.boxplot(quas, vert=False)
plt.title("quas box")
plt.xlabel("quas value")
plt.show()
